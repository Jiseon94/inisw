# %%
import re

# %%
data = '''
    홍길동 9203819-1234567
    김개똥 주민번호 : 8362746-3874649
'''

# %%
for d in data.splitlines()[1:]:
    lr = d.split()
    num = lr[1].split('-')
    print(f'{lr[0]} {num[0]}-'+'*'*len(num[1]))
# Out:
# 홍길동 9203819-*******
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 lr = d.split()
#       3 num = lr[1].split('-')
# ----> 4 print(f'{lr[0]} {num[0]}-'+'*'*len(num[1]))
#
# IndexError: list index out of range

# %%
print(re.sub('[0-9]{7}', '*******', data))

# %%
data = 'Life is too short.'
re.match('Life', data)
# Out:
# <re.Match object; span=(0, 4), match='Life'>

# %%
data = 'Life is too short.'
re.match('short', data)
#결과가 안나옴. 왜냐면 match 는 앞에서부터 봐야해서

# %%
data = 'Life is too short.'
re.search('Life', data)
# Out:
# <re.Match object; span=(0, 4), match='Life'>

# %%
re.search('short\.$', data)
# Out:
# <re.Match object; span=(12, 18), match='short.'>

# %%
re.findall('[a-zA-Z]+', data)
# Out:
# ['Life', 'is', 'too', 'short']

# %%
re.search('(ABC)+', 'ABCABCABCOK').group(0)
# Out:
# 'ABCABCABC'

# %%
re.search('(ABC)+', 'ABCABCABCOK').group(1) #그룹핑 한걸 뽑아낸걸 캡쳐링 했다라고 함
# Out:
# 'ABC'

# %%
re.search('(?:ABC)+(OK)', 'ABCABCABCOK').groups()
# Out:
# ('OK',)

# %%
re.sub(r'([가-힣])([가-힣]+)', r'\g<2> \g<1>','홍길동')
# Out:
# '길동 홍'

# %%
print('\n', r'\n')
r'\n'
# Out:
#  \n
# '\\n'

# %%
re.escape('\n')
# Out:
# '\\\n'

# %%
re.escape('\n'), re.escape(r'\n'), re.escape('\g')
# Out:
# ('\\\n', '\\\\n', '\\\\g')

# %%
# \\\n => \newline

# %%
data = '''
    010-1234-5675
    123-3838-4737
    031-3833-2838
    02-3837-3833
    02-3773-1737
    02 1234 1234
    02.1234.1234
    02)1234-1234
    02_1234_1234
    01012341234
    +82 010 3005 2119
    공1공 일2삼4 1234
'''

re.findall(r'(([0-9]{3})-([0-9]{4})-([0-9]{4}))', data)
re.findall(r'(([0]\d{1,2})-(\d{4})-(\d{4}))', data)
re.findall(r'(([0]\d{1,2})\D*(\d{4})\D*(\d{4}))', data)
#국가코드까지 인지하는 정규식을 만들어줄거임.
re.findall(r'((?:[+]?\d{1,2})?\D*([0]\d{1,2})\D*(\d{4})\D*(\d{4}))', data)
rst = re.sub('[공영]', '0', '공1공 일2삼4 1234')
rst = re.sub('일|하나', '1', rst)
rst = re.sub('[삼셋]', '3', rst)
#패턴을 만들어놓자
p1 = re.compile('')
p2 = 
p3 ...
patterns = [p1, p2, p3]
    
d = ''
for p in patterns[0:]:
    d = p.sub(?, d)

re.sub(
    '[삼셋]', '3'
    , re.sub(
        '일|하나', '1'
    )
)
print(rst)
re.findall()

# %%
#email
# id@도메인 
data ='''
    id@gmail.com
    abcd eAASD99@gmail.com
    _dasfasdf@gmail.com
    234230@gmail.com
    한글@gmail.com
    sadflkjas@gmail.co.kr
    sadflkjas@mail.gmail.com.kr
'''
# re.findall(r'(([a-z])+)@([a-z]+\.[a-z]_))', data)
# re.findall(r'(([a-z])+)@([a-z]+\.[a-z]+))', data)
# re.findall(r'(([a-zA-Z0-9]){5,})@([a-z]+\.[a-z]+))', data)
# re.findall(r'\b(([a-z](?:\w|[.]){4,})@([a-z]+\.[a-z]+)\b)', data)
re.findall(r'\b(([a-z](?:\w|[.]){4,})@([a-z0-9_-]+(?:[.][a-z]+)+)\b)', data)
# Out:
# [('eAASD99@gmail.com', 'eAASD99', 'gmail.com'),
#  ('sadflkjas@gmail.co.kr', 'sadflkjas', 'gmail.co.kr'),
#  ('sadflkjas@mail.gmail.com.kr', 'sadflkjas', 'mail.gmail.com.kr')]

# %%
data = '''
    http://www.naver.com
    https://www.naver.com
    ftp://www.naver.com
    http://search.naver.com/path1/path2/search.nhn?q=어쩌고&k=value
'''

re.findall(r'(http://)', data)
re.findall(r'(https?://)', data)
re.findall(r'(https?://([a-z0-9_\-]+(?:[.][a-z]+)+))', data)
re.findall(r'(https?://([a-z0-9_\-]+(?:[.][a-z]+)+)((?:/[a-z0-9_\-.]+)*))', data)
re.findall(r'(https?://([a-z0-9_\-]+(?:[.][a-z]+)+)((?:/[a-z0-9_\-.]+)*)\??((?:\&?\w+=\w+)+))', data)
# Out:
# [('http://search.naver.com/path1/path2/search.nhn?q=어쩌고&k=value',
#   'search.naver.com',
#   '/path1/path2/search.nhn',
#   'q=어쩌고&k=value')]

# %%
from requests import request
from requests.exceptions import HTTPError
from time import sleep

def download(url, params={}, method='GET', retries=3):
    resp = None
    
    try:
        resp = request(method, url,
                       params=params if method=='GET' else {},
                       data=params if method=='POST' else {},
                       headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.366'}
                      )
        resp.raise_for_status()
    except HTTPError as e:
        if 500 <= e.response.status_code:
            if retries > 0:
                sleep(3)
                resp = download(url, params=params,
                                method=method,
                                retries=retries-1)
            else:
                print('재방문 횟수 초과')
        else:
            print('Request', resp.request.headers)
            print('Response', e.response.headers)
        
    return resp

# %%
# resp = download('https://www.google.com/search?q=%EC%B9%B4%EB%A6%AC%EB%82%98&sca_esv=564553619&sxsrf=AB5stBi5KL-AELt9jXyRl5mk0reC8CvAIA%3A1694483499074&ei=K8T_ZMuUBKbP1e8Pyqul6Ao&ved=0ahUKEwiL1qj4-qOBAxWmZ_UHHcpVCa0Q4dUDCBA&uact=5&oq=%EC%B9%B4%EB%A6%AC%EB%82%98&gs_lp=...&sclient=gws-wiz-serp')

#네이버
# resp = download('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%B9%B4%EB%A6%AC%EB%82%98')

#다음
resp = download('https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%EC%B9%B4%EB%A6%AC%EB%82%98')

# %%
resp.status_code, resp.headers #구글
# Out:
# (200,
# ...

# %%
resp.status_code, resp.headers #네이버
# Out:
# (200,
# ...

# %%
resp.status_code, resp.headers #다음
# Out:
# (200,
#  {'Date': 'Tue, 12 Sep 2023 02:33:27 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Set-Cookie': 'uvkey=19476421-5955-4b2d-a81a-64295b554919; Path=/; Domain=search.daum.net; Expires=Fri, 09 Sep 2033 02:33:27 GMT; Max-Age=315360000, _ksk=19476421-5955-4b2d-a81a-64295b554919; Path=/; Domain=search.daum.net; Expires=Wed, 13 Sep 2023 02:33:27 GMT; Max-Age=86400, DTQUERY=%EC%B9%B4%EB%A6%AC%EB%82%98; Path=/; Domain=search.daum.net; Expires=Wed, 11 Sep 2024 02:33:27 GMT; Max-Age=31536000, ODT=IIMZ_NNSZ_TWAZ_1DVZ_DICZ_IVRZ_LB2Z; Path=/; Domain=search.daum.net; Expires=Wed, 11 Sep 2024 02:33:27 GMT; Max-Age=31536000, DDT=GG2Z_VOIZ_SNYZ_MS2Z; Path=/; Domain=search.daum.net; Expires=Wed, 11 Sep 2024 02:33:27 GMT; Max-Age=31536000', 'Server': 'kws', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Encoding': 'gzip'})

# %%
resp.encoding
# Out:
# 'UTF-8'

# %%
#구글
re.search('<title>(.*)</title>', resp.text
          , flags=re.IGNORECASE).group(1)
# Out:
# '카리나 - Google 검색'

# %%
#네이버
re.search('<title>(.*)</title>', resp.text
          , flags=re.IGNORECASE).group(1)
# Out:
# '카리나 : 네이버 통합검색'

# %%
#다음
re.search('<title>(.*)</title>', resp.text
          , flags=re.IGNORECASE).group(1)
# Out:
# '카리나 &ndash; Daum 검색'

# %%
#구글
len(re.findall('href=".+?"', resp.text))
# Out:
# 90

# %%
#네이버
len(re.findall('href=".+?"', resp.text))
# Out:
# 624

# %%
#다음
len(re.findall('href=".+?"', resp.text))
# Out:
# 457

# %%
#구글
re.findall('href="[^"]+?"', resp.text)
re.findall('<a jsname="UWckNb" href="([^"]+?)"', resp.text)
# Out:
# ['https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98(aespa)',
#  'https://ko.wikipedia.org/wiki/%EC%B9%B4%EB%A6%AC%EB%82%98_(%EA%B0%80%EC%88%98)',
#  'https://www.instagram.com/karina_aespas_/',
#  'https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98(aespa)?rev=3170',
#  'https://www.youtube.com/watch?v=prSFnMkjtlI',
#  'https://www.youtube.com/watch?v=gO_ONOnzH-s']

# %%
#네이버
re.findall('href="[^"]+?"', resp.text)
re.findall('<a target="_blank" href="([^"]+?)"', resp.text)
# Out:
# ['https://keep.naver.com/',
#  'https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98%28aespa%29',
#  'https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98%28aespa%29',
#  'https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98%28aespa%29',
#  'https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98%28aespa%29',
#  'https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98%28aespa%29',
#  'https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98%28aespa%29',
#  'https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98',
#  'https://keep.naver.com/',
#  'https://tencarat.co.jp/karina/',
#  'https://tencarat.co.jp/karina/',
#  'https://papago.naver.net/website?source=ja&amp;target=ko&amp;url=https://tencarat.co.jp/karina/',
#  'https://tencarat.co.jp/karina/',
#  'https://tencarat.co.jp/karina/',
#  'https://keep.naver.com/',
#  'https://hajuns1469-upandgo.com/337',
#  'https://hajuns1469-upandgo.com/337',
#  'https://hajuns1469-upandgo.com/337',
#  'https://hajuns1469-upandgo.com/337',
#  'https://hajuns1469-upandgo.com/337',
# ...

# %%
#다음
re.findall('href="[^"]+?"', resp.text)
re.findall('<a class="tit_main" href="([^"]+?)"', resp.text)
# Out:
# []

# %%
len(re.findall('<img ', resp.text))
# Out:
# 62

# %%
re.findall('<img alt=".+?" id=".?" src="(.+?)"', resp.text)
# Out:
# []

# %%
#선생님 풀이
resp = download('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%B9%B4%EB%A6%AC%EB%82%98')

# %%
resp.status_code, resp.headers #네이버
# Out:
# (200,
#  {'Date': 'Tue, 12 Sep 2023 02:35:03 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'page_uid=in/MSwprvhGssCdJ8Xlssssss3Z-203300; path=/; domain=.naver.com, _naver_usersession_=eIqk20dVmlMWfIoJdkC5bA==; path=/; expires=Tue, 12-Sep-23 02:40:03 GMT; domain=.naver.com, nx_ssl=2; Domain=.naver.com; Path=/; Expires=Thu, 12-Oct-2023 02:35:03 GMT;', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; report=/p/er/post/xss', 'Cache-Control': 'no-cache, no-store, must-revalidate, max-age=0', 'Pragma': 'no-cache', 'Referrer-Policy': 'unsafe-url', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Server': 'nxg', 'Accept-CH': 'Sec-CH-UA, Sec-CH-UA-Arch, Sec-CH-UA-Bitness, Sec-CH-UA-Full-Version-List, Sec-CH-UA-Mobile, Sec-CH-UA-Model, Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version, Sec-CH-UA-WoW64'})

# %%
resp.text
# Out:
# '<!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="카리나 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'카리나\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'카리나\'의 네이버 통합검색 결과입니다."> <title>카리나 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic
# ...

# %%
re.findall('<a(?: target="_blank")? href="([^"]+?)" class="(?:link_tit|news_tit)"'
           , resp.text)
# Out:
# ['https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98%28aespa%29',
#  'https://tencarat.co.jp/karina/',
#  'http://sports.khan.co.kr/news/sk_index.html?art_id=202309111724003&sec_id=540101&pt=nv',
#  'https://www.starnewskorea.com/stview.php?no=2023091118032779966',
#  'http://sports.chosun.com/news/ntype.htm?id=202309110100082270009731&servicedate=20230911',
#  'http://www.osen.co.kr/article/G1112181012',
#  'https://hajuns1469-upandgo.com/337',
#  'https://ko.wikipedia.org/wiki/%EC%B9%B4%EB%A6%AC%EB%82%98_%28%EA%B0%80%EC%88%98%29',
#  'https://www.instagram.com/AESPA_OFFICIAL/']

# %%
#웹사이트 html의 태그와 내가 서치한 태그 정보가 서로 다르므로, 내가 서칭한 내용에서 찾아줘야한다.
resp.text
# Out:
# '<!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="카리나 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'카리나\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'카리나\'의 네이버 통합검색 결과입니다."> <title>카리나 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic
# ...

# %%
re.findall('<img src="data:image/gif;base64,[^"]+"', resp.text)
# Out:
# ['<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."',
#  '<img src="..."']

# %%
#항상 원문(원본)가지고 봐야해. 변수나 경우의 수가 많다보니, 눈으로 직접 뒤져가며 확인을 해야한다.

# %%
# re.findall('<a((?:\s+[^=]+?="[^"]+?")+)></a>', resp.text)
# re.findall('<a((\s+[^=]+?="[^"]+?")+)></a>', resp.text)
# re.findall('<a(?:(?:\s+([^=]+?="[^"]+?"))+)></a>', resp.text)
# re.findall('<a(?:(?:\s+([^=]+?="[^"]+?"))+)>(.+?)</a>', resp.text)
re.findall('<a(?:(?:\s+(?:[^=]+?="[^"]+?"))+)\s+href="([^"])"(?:(?:\s+))>(.+?)</a>', resp.text)
# Out:
# []

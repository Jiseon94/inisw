# %%
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in c:\users\user\appdata\roaming\python\python310\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from beautifulsoup4) (2.5)

# %%
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: html5lib in c:\users\user\appdata\roaming\python\python310\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\user\appdata\roaming\python\python310\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\user\appdata\roaming\python\python310\site-packages (from html5lib) (0.5.1)

# %%
from bs4 import BeautifulSoup

# %%
import html5lib

# %%
html = '''
    <html>
        <head></head>
        <body>
            <div>
                <a href = "/link1">링크1</a>
            </div>
        </body>
    </html>
'''

dom = BeautifulSoup(html, 'html.parser')

# %%
type(dom)
# Out:
# bs4.BeautifulSoup

# %%
dom
# Out:
# <html>
# <head></head>
# <body>
# <div>
# <a href="/link1">링크1</a>
# </div>
# </body>
# </html>

# %%
dom.html
# Out:
# <html>
# <head></head>
# <body>
# <div>
# <a href="/link1">링크1</a>
# </div>
# </body>
# </html>

# %%
dom.div
# Out:
# <div>
# <a href="/link1">링크1</a>
# </div>

# %%
dom.a
# Out:
# <a href="/link1">링크1</a>

# %%
type(dom.html), dom.html.body.div, dom.div
# Out:
# (bs4.element.Tag,
#  <div>
#  <a href="/link1">링크1</a>
#  </div>,
#  <div>
#  <a href="/link1">링크1</a>
#  </div>)

# %%
dom.html.body.div is dom.div
# Out:
# True

# %%
dom.a.attrs['href']
# Out:
# '/link1'

# %%
dom.a.has_attr('href')
# Out:
# True

# %%
dom.div.attrs['href'] if dom.div.has_attr('href') else None

# %%
type(dom.a.img)
# Out:
# NoneType

# %%
dom.a.img
#우리가 확인해야할 것
# 1. None -> 객체(노드) 확인 
# 2. has_attr -> 속성 확인
# 3. attrs 를 가져오면 된다.

# %%
html = '''
<div id = 'result1'>
<p class=row>
<a class = 'red' href = "/link1">링크1</a>
<a class = 'blue' href = "/link1">링크2</a>
</p>
</div>
<div id = 'result2'>
<p class=row>
<a class = 'red' href = "/link1">링크1</a>
<a class = 'blue' href = "/link1">링크2</a>
</p>
</div>
<div id = 'result3'>
<p class=row>
<a class = 'red' href = "/link1">링크1</a>
<a class = 'blue' href = "/link1">링크2</a>
</p>
</div>
'''

dom = BeautifulSoup(html, 'html.parser')
# dom = BeautifulSoup(html, 'lxml')
# dom = BeautifulSoup(html, "html5lib")

# %%
dom
# Out:
# <div id="result1">
# <p class="row">
# <a class="red" href="/link1">링크1</a>
# <a class="blue" href="/link1">링크2</a>
# </p>
# </div>
# <div id="result2">
# <p class="row">
# <a class="red" href="/link1">링크1</a>
# <a class="blue" href="/link1">링크2</a>
# </p>
# </div>
# <div id="result3">
# <p class="row">
# <a class="red" href="/link1">링크1</a>
# <a class="blue" href="/link1">링크2</a>
# </p>
# </div>

# %%
# 우리가 확인해야할것.
# 완벽하게 구조화되지 않아도 문제 없다.
# attributes(ke=v), ' " X

# %%
dom
# Out:
# <html><body><div id="result">
# <p class="row">
# <a class="red" href="/link1">링크1</a>
# <a class="blue" href="/link1">링크2</a>
# </p>
# </div>
# </body></html>

# %%
# [_ for _ in dom.p.children]
[type(_) for _ in dom.p.contents]
# [type(_) for _ in dom.p.contents if type(_) is] #_ 는 이전에 값을 말한다. 
# [type(node) for node in dom.p.contents if type(node) is]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
dom.a.attrs
# Out:
# {'class': ['red'], 'href': '/link1'}

# %%
# 우리가 항상 봐야할 값들은 id, class, 경우에 따라서 name(form 태그를 쓸때)
# html 입장에서 보면 tag(<>) 라고 하고 , dom 입장에서 보면 node(Tag(<>)) 라고 한다.
# id는 고유한 값이다. 중복 x
# class 는 공통된 속성이다. 다중상속이 가능하다. 여러개 있을 수 있다. 
dom.div.attrs, dom.a.attrs
# Out:
# ({'id': 'result'}, {'class': ['red'], 'href': '/link1'})

# %%
#탐색하는 방법 find 계열의 함수
#camel 이름은 옛날 버전이니까 쓰지마라, snake 이름을 써라.
#다른 사람이 보고 훔쳐가지말라고, id랑 class 속성값을 주지 않고, 위치로 찾게 만들었다.
dom.find('a')
#첫번째꺼만 매칭이된다!

# dom.find('a') is dom.a
# Out:
# <a class="red" href="/link1">링크1</a>

# %%
dom.find(attrs={'id':'result1'})
# Out:
# <div id="result1">
# <p class="row">
# <a class="red" href="/link1">링크1</a>
# <a class="blue" href="/link1">링크2</a>
# </p>
# </div>

# %%
dom.find(attrs={'id':'result1'}) is dom.div
# Out:
# True

# %%
dom.find(attrs={'id':'result2'}).a
# Out:
# <a class="red" href="/link1">링크1</a>

# %%
dom.find(attrs={'id':'result2'}).a is dom.a
# Out:
# False

# %%
dom.a
# Out:
# <a class="red" href="/link1">링크1</a>

# %%
dom.find('a', recursive=False) #none 이다.

# %%
dom.find('html', recursive=False)

# %%
dom.find('a', recursive=True)
# Out:
# <a class="red" href="/link1">링크1</a>

# %%
# recursive : 탐색범위. True or False <= 내 자식을 찾을지, 내 자손을 찾을지?

# %%
dom.div.contents
# Out:
# ['\n',
#  <p class="row">
#  <a class="red" href="/link1">링크1</a>
#  <a class="blue" href="/link1">링크2</a>
#  </p>,
#  '\n']

# %%
dom.div.p.find_all(recursive=False)[0] is dom.a
# Out:
# True

# %%
dom.div.p.find_all(recursive=False)[1]
# Out:
# <a class="blue" href="/link1">링크2</a>

# %%
dom.find(string='링크1').find_parent() is dom.a
# Out:
# True

# %%
dom.find_all(recursive=False, limit=1)[0] is dom.div
# Out:
# True

# %%
dom.find_all(recursive=False, limit=1)[0] is dom.find(recursive=False)
# Out:
# True

# %%
#정규식 섞어서 써보기
import re

# %%
dom.find(text=re.compile('1$')) is dom.find(text='링크1')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11044\2941528018.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   dom.find(text=re.compile('1$')) is dom.find(text='링크1')
# True

# %%
dom.find(attrs={'id':re.compile('1$')})
# Out:
# <div id="result1">
# <p class="row">
# <a class="red" href="/link1">링크1</a>
# <a class="blue" href="/link1">링크2</a>
# </p>
# </div>

# %%
dom.find(attrs={'id':re.compile('1$')}) is dom.find(attrs={'id':'result1'})
# Out:
# True

# %%
#부모 건들여보기
dom.a.find_parent() is dom.p
# Out:
# True

# %%
dom.p is dom.find('p')
# Out:
# True

# %%
dom.find('p') is dom.find(attrs={'class':'row'})
# Out:
# True

# %%
dom.find('p').find_all('a')[-1].find_parent() is dom.p
# Out:
# True

# %%
dom.a.find_parent('div')
# Out:
# <div id="result1">
# <p class="row">
# <a class="red" href="/link1">링크1</a>
# <a class="blue" href="/link1">링크2</a>
# </p>
# </div>

# %%
dom.p.find_parents()
# Out:
# [<div id="result1">
#  <p class="row">
#  <a class="red" href="/link1">링크1</a>
#  <a class="blue" href="/link1">링크2</a>
#  </p>
#  </div>,
#
#  <div id="result1">
#  <p class="row">
#  <a class="red" href="/link1">링크1</a>
#  <a class="blue" href="/link1">링크2</a>
#  </p>
#  </div>
#  <div id="result2">
#  <p class="row">
#  <a class="red" href="/link1">링크1</a>
#  <a class="blue" href="/link1">링크2</a>
#  </p>
#  </div>
#  <div id="result3">
#  <p class="row">
#  <a class="red" href="/link1">링크1</a>
#  <a class="blue" href="/link1">링크2</a>
#  </p>
#  </div>]

# %%
for node in dom.a.find_parents(limit=3):
    print(node.name)
# Out:
# p
# div
# [document]

# %%
#parameter 보기
dom.a.find_next_siblings()
# Out:
# [<a class="blue" href="/link1">링크2</a>]

# %%
dom.find_all(['a'])
# Out:
# [<a class="red" href="/link1">링크1</a>,
#  <a class="blue" href="/link1">링크2</a>,
#  <a class="red" href="/link1">링크1</a>,
#  <a class="blue" href="/link1">링크2</a>,
#  <a class="red" href="/link1">링크1</a>,
#  <a class="blue" href="/link1">링크2</a>]

# %%
dom.find_all(['p'])
# Out:
# [<p class="row">
#  <a class="red" href="/link1">링크1</a>
#  <a class="blue" href="/link1">링크2</a>
#  </p>,
#  <p class="row">
#  <a class="red" href="/link1">링크1</a>
#  <a class="blue" href="/link1">링크2</a>
#  </p>,
#  <p class="row">
#  <a class="red" href="/link1">링크1</a>
#  <a class="blue" href="/link1">링크2</a>
#  </p>]

# %%
from requests import get
url = 'http://pythonscraping.com/pages/page3.html'
resp = get(url)

# %%
#잘 받았는지 확인하기.
resp.headers['content-type']
# Out:
# 'text/html'

# %%
dom = BeautifulSoup(resp.content, 'html.parser')

# %%
[node.name for node in dom.div.find_all(recursive=False)]
# Out:
# ['img', 'h1', 'div', 'table', 'div']

# %%
[node for node in dom.div.find_all(recursive=False)][-1].attrs

# %%
[node.name for node in dom.body.find_all(recursive=False)]
# Out:
# ['div']

# %%
# dom = BeautifulSoup(resp.content, 'html5lib')
dom = BeautifulSoup(resp.content, 'html.parser')

# %%
[node.name for node in dom.table.find_all_next(recursive=False)]
# Out:
# ['tr',
#  'th',
#  'th',
#  'th',
#  'th',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'tr',
#  'td',
#  'td',
#  'span',
#  'td',
#  'td',
#  'img',
#  'div',
#  'br']

# %%
#<p>로 시작해서 찾아보기. 근데 footer 안에 p가 있다.
base = dom.find(attrs={'id':'footer'})

# %%
#형제들 중 가장 첫번째, 부모의 첫번째 자식
#내입장(base)에서 보면 밑에 노드에서부터 타고타고 올라가다보니 
# 가장 마지막에 찾아지니 -1 인덱스를 해야한다. 
base.find_previous_siblings()[-1]
# Out:
# <img src="../img/gifts/logo.jpg" style="float:left;"/>

# %%
base.find_previous_siblings()[-1] is base.find_parent().find()
# Out:
# True

# %%
#이번에는 table 로 넘어가보자
table = base.find_previous_sibling()

# %%
len(table.find_all(recursive=False))
# Out:
# 6

# %%
table.find_all(recursive=False)[-1].find_all(recursive=False)[-1]
# Out:
# <td>
# <img src="../img/gifts/img6.jpg"/>
# </td>

# %%
#마지막 열에 있는 애들 다 가져오기
for tr in table.find_all(recursive=False)[1:]:
    td = tr.find_all(recursive=False)[-1]
    print(td.find('img').attrs['src'])
# Out:
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %%
#가격 뽑으려면?
for tr in table.find_all(recursive=False)[1:]:
    td = tr.find_all(recursive=False)[-2]
    print(re.sub(r'\s+', '', td.text))
# Out:
# $15.00
# $10,000.52
# $10,005.00
# $0.50
# $1.50

# %%
table.find_all('img', attrs={'src':re.compile('jpg$')})
# Out:
# [<img src="../img/gifts/img1.jpg"/>,
#  <img src="../img/gifts/img2.jpg"/>,
#  <img src="../img/gifts/img3.jpg"/>,
#  <img src="../img/gifts/img4.jpg"/>,
#  <img src="../img/gifts/img6.jpg"/>]

# %%
table.find_all(attrs={'src':re.compile('jpg$')})
# Out:
# [<img src="../img/gifts/img1.jpg"/>,
#  <img src="../img/gifts/img2.jpg"/>,
#  <img src="../img/gifts/img3.jpg"/>,
#  <img src="../img/gifts/img4.jpg"/>,
#  <img src="../img/gifts/img6.jpg"/>]

# %%
table.find_all(string=re.compile('\$[0-9,.]+'))
# Out:
# ['\n$15.00\n', '\n$10,000.52\n', '\n$10,005.00\n', '\n$0.50\n', '\n$1.50\n']

# %%
[node.find_parent() for node in 
table.find_all(string=re.compile('\$[0-9,.]+'))
]
# Out:
# [<td>
#  $15.00
#  </td>,
#  <td>
#  $10,000.52
#  </td>,
#  <td>
#  $10,005.00
#  </td>,
#  <td>
#  $0.50
#  </td>,
#  <td>
#  $1.50
#  </td>]

# %%
import sys

print(sys.version)
# Out:
# 3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]

# %%
print(BeautifulSoup.version)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 print(BeautifulSoup.version)
#
# AttributeError: type object 'BeautifulSoup' has no attribute 'version'

# %%
from requests.compat import urljoin

for node in dom.find_all('img', attrs={'src':re.compile('jpg$')}):
    print(node.attrs['src'])
    print(urljoin(resp.request.url, node.attrs['src']))
# Out:
# ../img/gifts/logo.jpg
# https://pythonscraping.com/img/gifts/logo.jpg
# ../img/gifts/img1.jpg
# https://pythonscraping.com/img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# https://pythonscraping.com/img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# https://pythonscraping.com/img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# https://pythonscraping.com/img/gifts/img4.jpg
# ../img/gifts/img6.jpg
# https://pythonscraping.com/img/gifts/img6.jpg

# %%
#상대주소를 절대주소의 형태로 바꾸면 이렇게 되는거다.

# %%
url = 'https://pythonscraping.com/img/gifts/img2.jpg'
resp = get(url)

# %%
resp.headers
# Out:
# {'Server': 'nginx', 'Date': 'Wed, 13 Sep 2023 02:26:38 GMT', 'Content-Type': 'image/jpeg', 'Content-Length': '58424', 'Last-Modified': 'Mon, 04 Aug 2014 00:49:04 GMT', 'Connection': 'keep-alive', 'ETag': '"53ded880-e438"', 'X-Powered-By': 'PleskLin', 'Accept-Ranges': 'bytes'}

# %%
resp.text
# Out:
# '����\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00��\x00<CREATOR: gd-jpeg v1.0 (using IJG JPEG v62), quality = 100\n��\x00C��\x00C��\x00\x11\x08\x01\x04\x01,\x03\x01"\x00\x02\x11\x01\x03\x11\x01��\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b��\x00�\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142���\x08#B��\x15R��$3br�\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz���������������������������������������������������������������������������\x00\x1f\x01\x00\x03\x01\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b��\x00�\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2�\x08\x14B����\t#3R�\x15br�\n\x16$4�%�\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz��������������������������������������������������������������������������\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00���=�\x003�4c�����\x00\x1a��@�Q��\x02�ܟ�@�?眂G�\tp=�\x003�4`{�g�j\x10=\x7f�A#��Jp\\�s��\'�<~��\x00I�����h�����As\u05cf�ؑ�P\x17?�\x07��O�w��\tp=�\x003�4`{�g�j ������Oր�d�\x00�\t�����\tp=�\x003ǿZ6�:��\x7fNx�v��~��84`�\x7f�{~\x1f�"�%�0:�g����{�g�j\x103�\x7f�#\x1d\x0f\'\x07\x14�O\x18���\x00��\x00�\x03��?�F\x07��\x7fƢǧ��玽\x7f�\\�\n�1�\x0f�\x1d\x7fǿ��\x00K�{�g�h������[zw��ߨ��{\x0c��o#�\x0e?Q����\\\x1a\x00�h��;�\x7f~���\x18\x1e�\x00������\x0fP:���\x1f��\x1bO�H\uf79f��>��%�=�\x003�4\x05\x1e�=O��AI�������x�g��\x7f��\x00\x10\tv�\x7f��\x00�\x01G��H��\x0e�����?:]�g���\x1e���\x00U\x00K�{�g�h������[}�x����\x0c\x7f^(�q��\x1d����y�\tp=�\x003�u�F��۹�~���������_�F�=����9����\x00�\x03߷s�=��=�w=�\x1fʡ���\x00$�z}1�
6\x00\x97\x03\xdf\xb7s\xfe=\xa8\xda=\xfbw=\xbf\x1f\xca\xa1\xc1\xf4\xff\x00$\xe0z}1\xd79\xfc\x0c\x1f\xc8\x03\xf9\xe3\x1f\xcf\xf9\xd0\x04\xdbG\xbf\xe6\x7f\xc6\x8d\xa3\xdf\xb7s\xd8\xfd\x7f/C^\x7f\xe2?\x89\xdf\x0e| \xed\x17\x8a<s\xe1=\x06t`\x8dk\xa9\xeb\xdae\xad\xe0v\xce\x17\xecr\\\xad\xd1c\x83\x80!$\x91^w\'\xedM\xfb=C}\ ...

# %%
len(resp.content)
# Out:
# 58424

# %%
with open(resp.request.url.split('/')[-1], 'wb') as fp:
    fp.write(resp.content)

# %%
resp.request.url.split('/')[-1]
# Out:
# 'img2.jpg'

# %%
# !dir -al *.jpg
# Out:
#  C 드라이브의 볼륨: Windows
#  볼륨 일련 번호: 34F5-71B4
#
#  C:\Users\user 디렉터리
#
#
#  C:\Users\user 디렉터리
#
# 2023-09-13  오전 11:28            58,424 img2.jpg
#                1개 파일              58,424 바이트
#                0개 디렉터리  129,036,353,536 바이트 남음

# %%
#===============실습===============

# %%
from requests import request
from requests.exceptions import HTTPError
from time import sleep

def download(url, params={}, method='GET', retries=3):
    resp = None
    
    try:
        resp = request(method, url,
                       params=params if method=='GET' else {},
                       data=params if method=='POST' else {},
                       headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.366'}
                      )
        resp.raise_for_status()
    except HTTPError as e:
        if 500 <= e.response.status_code:
            if retries > 0:
                sleep(3)
                resp = download(url, params=params,
                                method=method,
                                retries=retries-1)
            else:
                print('재방문 횟수 초과')
        else:
            print('Request', resp.request.headers)
            print('Response', e.response.headers)
        
    return resp

# %%
resp = download('https://www.google.com/search?q=%EC%B9%B4%EB%A6%AC%EB%82%98&sca_esv=564895683&sxsrf=AB5stBhT7PNbb-8ENLfatzMguKl4EfH-iA%3A1694572614742&source=hp&ei=RiABZcyCK8ep-Qac9Z-IBg&iflsig=AD69kcEAAAAAZQEuVpUHbfiLeeOEopgf0UnD2VBH6fVq&ved=0ahUKEwjMvfv1xqaBAxXHVN4KHZz6B2EQ4dUDCAs&uact=5&oq=%EC%B9%B4%EB%A6%AC%EB%82%98&gs_lp=Egdnd3Mtd2l6IgnsubTrpqzrgpgyBxAjGIoFGCcyCBAuGIAEGLEDMgQQABgDMgQQABgDMgUQABiABDIFEAAYgAQyBRAAGIAEMgUQABiABDIFEAAYgAQyBRAAGIAESOcIUJ8EWNMHcAJ4AJABAZgBiQGgAe0FqgEDMC42uAEDyAEA-AEBqAIKwgIHECMY6gIYJ8ICBBAjGCfCAgsQABiABBixAxiDAcICERAuGIAEGLEDGIMBGMcBGNEDwgIFEC4YgATCAggQABiABBixAw&sclient=gws-wiz')

# %%
resp.status_code, resp.headers
# Out:
# (200,
#  {'Content-Type': 'text/html; charset=UTF-8', 'Date': 'Wed, 13 Sep 2023 02:37:02 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Strict-Transport-Security': 'max-age=31536000', 'Content-Security-Policy': "object-src 'none';base-uri 'self';script-src 'nonce-AovD6Xz-ZqWXgIsvNKul-g' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/cdt1", 'Cross-Origin-Opener-Policy': 'same-origin-allow-popups; report-to="gws"', 'Report-To': '{"group":"gws","max_age":2592000,"endpoints":[{"url":"https://csp.withgoogle.com/csp/report-to/gws/cdt1"}]}', 'Accept-CH': 'Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version, Sec-CH-UA-Full-Version, Sec-CH-UA-Arch, Sec-CH-UA-Model, Sec-CH-UA-Bitness, Sec-CH-UA-Full-Version-List, Sec-CH-UA-WoW64', 'Permissions-Policy': 'unload=()', 'Origin-Trial': 'Ap+qNlnLzJDKSmEHjzM5ilaa908GuehlLqGb6ezME5lkhelj20qVzfv06zPmQ3LodoeujZuphAolrnhnPA8w4AIAAABfeyJvcmlnaW4iOiJodHRwczovL3d3dy5nb29nbGUuY29tOjQ0MyIsImZlYXR1cmUiOiJQZXJtaXNzaW9uc1BvbGljeVVubG9hZCIsImV4cGlyeSI6MTY4NTY2Mzk5OX0=, , AiXjiJ+T6IWCA1/DjT4NIGVJqjDDnkuM9yezPeFtkepj+zD859x80LZVwj7MbyS2oM0KeZLpfj5YcBKyz9CkjAIAAABceyJvcmlnaW4iOiJodHRwczovL3d3dy5nb29nbGUuY29tOjQ0MyIsImZlYXR1cmUiOiJOb1ZhcnlTZWFyY2hQcmVmZXRjaCIsImV4cGlyeSI6MTcwNDQxMjc5OX0=', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2023-09-13-02; expires=Fri, 13-Oct-2023 02:37:02 GMT; path=/; domain=.google.com; Secure; SameSite=none, AEC=Ad49MVH5qgl8eRov0aHztuyy4DPo6pZJSXxq8VVSQ8-MxbArGVpZi-Ehdw; expires=Mon, 11-Mar-2024 02:37:02 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax, NID=511=K5T1iLbIXLXMdFiDPP27LrAwYkDIqP2c5BxBHYk_4MvXUAjRsZXPivhfbAdEupJ_a8mgSS48Aoq1xx3FIu7AxNap6QM3TT05ugwRje3VH1jiIRctExba_X-gGUe9rYvzztH8apb2F9Fbk2SXbO_c80AnLLueGglUDBjJY1_-I0A; expires=Thu, 14-Mar-2024 02:37:02 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=none', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'Transfer-Encoding': 'chunked'})

# %%
resp.encoding
# Out:
# 'UTF-8'

# %%
dom = BeautifulSoup(resp.text, 'html.parser')

# %%
dom.find_all('a', attrs={'jsname':'UWckNb'})
# Out:
# [<a data-ved="2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQFnoECCsQAQ" href="https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98(aespa)" jsaction="rcuQ6b:npT2md" jscontroller="M9mgyc" jsname="UWckNb" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;opi=89978449&amp;url=https://namu.wiki/w/%25EC%25B9%25B4%25EB%25A6%25AC%25EB%2582%2598(aespa)&amp;ved=2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQFnoECCsQAQ"><br/><h3 class="LC20lb MBeuO DKV0Md">카리나(aespa) - 나무위키</h3><div class="TbwUpd NJjxre iUh30 ojE3Fb"><span class="DDKf1c qSQKQd" style="height:26px;width:26px"><div aria-hidden="true" class="eqA2re UnOTSe Vwoesf"><img alt="" class="XNo5Ab" src="data:image/png;base64,..." style="height:26px;width:26px"/></div></span><div><span class="VuuXrf">나무위키</span><div class="byrV5b"><cite class="qLRx3b tjvcx GvPZzd cHaqb" role="text">https://namu.wiki<span class="dyjrff ob9lvb" role="text"> › 카리나(aespa)</span></cite></div></div></div></a>,
#  <a data-ved="2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQFnoECCgQAQ" href="https://www.instagram.com/karina_aespas_/" jsaction="rcuQ6b:npT2md" jscontroller="M9mgyc" jsname="UWckNb" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;opi=89978449&amp;url=https://www.instagram.com/karina_aespas_/&amp;ved=2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQFnoECCgQAQ"><br/><h3 class="LC20lb MBeuO DKV0Md">AESPA KARINA 카리나 (@karina_aespas_)</h3><div class="TbwUpd NJjxre iUh30 ojE3Fb"><span class="DDKf1c qSQKQd" style="height:26px;width:26px"><div aria-hidden="true" class="eqA2re UnOTSe Vwoesf"><img alt="" class="XNo5Ab" src="data:image/png;base64,..." style="height:26px;width:26px"/></div></span><div><span class="VuuXrf">Instagram</span><div class="byrV5b"><cite class="qLRx3b tjvcx GvPZzd cHaqb" role="text">https://www.instagram.com<span class="dyjrff ob9lvb" role="text"> › karina_aespas_</span></cite></div></div></div></a>,
#  <a data-ved="2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQFnoECCkQAQ" href="https://ko.wikipedia.org/wiki/%EC%B9%B4%EB%A6%AC%EB%82%98_(%EA%B0%80%EC%88%98)" jsaction="rcuQ6b:npT2md" jscontroller="M9mgyc" jsname="UWckNb" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;opi=89978449&amp;url=https://ko.wikipedia.org/wiki/%25EC%25B9%25B4%25EB%25A6%25AC%25EB%2582%2598_(%25EA%25B0%2580%25EC%2588%2598)&amp;ved=2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQFnoECCkQAQ"><br/><h3 class="LC20lb MBeuO DKV0Md">카
#  <a data-ved="2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQtwJ6BAgmEAI" href="https://www.youtube.com/watch?v=prSFnMkjtlI" jsaction="rcuQ6b:npT2md" jscontroller="M9mgyc" jsname="UWckNb" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;opi=89978449&amp;url=https://www.youtube.com/watch%3Fv%3DprSFnMkjtlI&amp;ved=2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQtwJ6BAgmEAI"><br/><h3 class="LC20lb MBeuO DKV0Md">#KARINA big girl making money #BetterThingsChallenge ...</h3><div class="TbwUpd NJjxre iUh30 ojE3Fb"><span class="DDKf1c qSQKQd" style="height:26px;width:26px"><div aria-hidden="true" class="eqA2re UnOTSe Vwoesf"><img alt="" class="XNo5Ab" src="..." style="height:26px;width:26px"/></div></span><div><span class="VuuXrf">YouTube</span><div class="byrV5b"><cite class="qLRx3b tjvcx GvPZzd cHaqb" role="text">https://www.youtube.com<span class="dyjrff ob9lvb" role="text"> › watch</span></cite></div></div></div></a>,
#  <a data-ved="2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQtwJ6BAgqEAI" href="https://www.youtube.com/watch?v=v63rTR68TdA" jsaction="rcuQ6b:npT2md" jscontroller="M9mgyc" jsname="UWckNb" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;opi=89978449&amp;url=https://www.youtube.com/watch%3Fv%3Dv63rTR68TdA&amp;ved=2ahUKEwiV2OD5xqaBAxVbXvEDHaxrBuYQtwJ6BAgqEAI"><br/><h3 class="LC20lb MBeuO DKV0Md">230625 aespa(에스파) 'Next Level' 카리나 KARINA 4K Cam ...</h3><div class="TbwUpd NJjxre iUh30 ojE3Fb"><span class="DDKf1c qSQKQd" style="height:26px;width:26px"><div aria-hidden="true" class="eqA2re UnOTSe Vwoesf"><img alt="" class="XNo5Ab" src="..." style="height:26px;width:26px"/></div></span><div><span class="VuuXrf">YouTube</span><div class="byrV5b"><cite class="qLRx3b tjvcx GvPZzd cHaqb" role="text">https://www.youtube.com<span class="dyjrff ob9lvb" role="text"> › watch</span></cite></div></div></div></a>]

# %%
# for node in dom.find_all(attrs={'jsname':'UWckNb'}):
#     print(node.text.strip())
#     print(node.attrs['href'])
#     print(node)

for node in dom.find_all('h3', attrs={'class':'LC20lb'}):
    print(node.text.strip())
    print(node.find_parent().attrs['href'])
    print(node)
# Out:
# 카리나(aespa) - 나무위키
# https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98(aespa)
# <h3 class="LC20lb MBeuO DKV0Md">카리나(aespa) - 나무위키</h3>
# AESPA KARINA 카리나 (@karina_aespas_)
# https://www.instagram.com/karina_aespas_/
# <h3 class="LC20lb MBeuO DKV0Md">AESPA KARINA 카리나 (@karina_aespas_)</h3>
# 카리나 (가수) - 위키백과, 우리 모두의 백과사전
# https://ko.wikipedia.org/wiki/%EC%B9%B4%EB%A6%AC%EB%82%98_(%EA%B0%80%EC%88%98)
# <h3 class="LC20lb MBeuO DKV0Md">카리나 (가수) - 위키백과, 우리 모두의 백과사전</h3>
# 카리나(aespa) (r3170 판)
# https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98(aespa)?rev=3170
# <h3 class="LC20lb MBeuO DKV0Md">카리나(aespa) (r3170 판)</h3>
# #PictureChallenge with #KARINA #GISELLE #HYO #효연 ...
# https://www.youtube.com/watch?v=gO_ONOnzH-s
# <h3 class="LC20lb MBeuO DKV0Md">#PictureChallenge with #KARINA #GISELLE #HYO #효연 ...</h3>
# #KARINA big girl making money #BetterThingsChallenge ...
# https://www.youtube.com/watch?v=prSFnMkjtlI
# <h3 class="LC20lb MBeuO DKV0Md">#KARINA big girl making money #BetterThingsChallenge ...</h3>
# 230625 aespa(에스파) 'Next Level' 카리나 KARINA 4K Cam ...
# https://www.youtube.com/watch?v=v63rTR68TdA
# <h3 class="LC20lb MBeuO DKV0Md">230625 aespa(에스파) 'Next Level' 카리나 KARINA 4K Cam ...</h3>

# %%
len(dom.find_all(attrs={'jsname':'UWckNb'}))
# Out:
# 7

# %%
for node in dom.find_all(attrs={'data-lpage':re.compile('youtube.com')}):
    print(node.attrs['data-lpage'])
# Out:
# https://www.youtube.com/watch?v=TqBXWlVKXrs
# https://www.youtube.com/watch?v=693lIQ4ZwoM

# %%
#실습 하나 더 해보기
for node in dom.find_all('img'
                         # , attrs={'src':re.compile('^data')}):
                        , attrs={'src':re.compile('(?:png|gif|bmp|jpg|jpeg)$')}):
    print(urljoin(resp.request.url, node.attrs['src']))
# Out:
# https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_92x30dp.png
# https://www.google.com/tia/tia.png

# %%
#네이버, 다음 검색결과에서 링크와 타이틀, 이미지

#네이버
resp = download('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%B9%B4%EB%A6%AC%EB%82%98')
# resp = download('https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%EC%B9%B4%EB%A6%AC%EB%82%98')

# %%
resp.status_code, resp.headers
# Out:
# (200,
#  {'Date': 'Wed, 13 Sep 2023 03:03:04 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'page_uid=idZEjsprvN8ssUWiPiwsssssscs-302710; path=/; domain=.naver.com, _naver_usersession_=bsUY3slYEXyzzQSqBiSuOg==; path=/; expires=Wed, 13-Sep-23 03:08:04 GMT; domain=.naver.com, nx_ssl=2; Domain=.naver.com; Path=/; Expires=Fri, 13-Oct-2023 03:03:04 GMT;', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; report=/p/er/post/xss', 'Cache-Control': 'no-cache, no-store, must-revalidate, max-age=0', 'Pragma': 'no-cache', 'Referrer-Policy': 'unsafe-url', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Server': 'nxg', 'Accept-CH': 'Sec-CH-UA, Sec-CH-UA-Arch, Sec-CH-UA-Bitness, Sec-CH-UA-Full-Version-List, Sec-CH-UA-Mobile, Sec-CH-UA-Model, Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version, Sec-CH-UA-WoW64'})

# %%
resp.encoding
# Out:
# 'UTF-8'

# %%
dom = BeautifulSoup(resp.text, 'html.parser')

# %%
for node in dom.find_all('a'
            , attrs={'class': re.compile('link_tit|news_tit|name_tit|total_tit')}):
    print(node.text)
    print(node.attrs['href'])
# Out:
# 카리나(aespa) - 나무위키
# https://namu.wiki/w/%EC%B9%B4%EB%A6%AC%EB%82%98%28aespa%29
# 香里奈 | TEN CARAT
# https://tencarat.co.jp/karina/
# “카리나 원해” 황민호, 大실망한 이유는?
# http://sports.khan.co.kr/news/sk_index.html?art_id=202309121448013&sec_id=540201&pt=nv
# 카리나, 중단발 사진 공개…단발 욕구↑
# http://sports.khan.co.kr/news/sk_index.html?art_id=202309111724003&sec_id=540101&pt=nv
# 카리나, 모자 커 보이는 착시효과..뉴욕시 '천사 강림' [스타IN★]
# https://www.starnewskorea.com/stview.php?no=2023091118032779966
# 내년 '워터밤'에서 보고 싶은★…1위 권은비·2위 카리나, 전소미는 몇위?
# http://sports.chosun.com/news/ntype.htm?id=202309110100082270009731&servicedate=20230911
# 에스파 카리나 나이 본명 과사 몸매 담아봤어요 - 하준샵1469
# https://hajuns1469-upandgo.com/337
# 카리나 (가수) - 위키백과 한국
# https://ko.wikipedia.org/wiki/%EC%B9%B4%EB%A6%AC%EB%82%98_%28%EA%B0%80%EC%88%98%29
# aespa 에스파(@aespa_official) • Instagram 사진 및 동영상
# https://www.instagram.com/AESPA_OFFICIAL/
# (230911) (귀염뽕짝 원정대) (신동) 카리나 아닌 칼집삼겹살 기상요정/못하는게 없는 만능캐/
# https://blog.naver.com/mimyo_sj/223209826730
# [귀염뽕짝 원정대] 새 기상 요정이 '에스파' 카리나?! 황민호 '기절초풍'! 오늘(월) 밤 10시 방송
# https://blog.naver.com/tv_chosun/223208125040
# 에스파 카리나 무보정 클라스
# https://blog.naver.com/secretinto/223186333400
# 에스파 카리나 패션, 사복패션, 의상, 코디
# https://blog.naver.com/23sksmssk/223210055924
# 갑자기 단발로 확 자르고 좋아요 폭발한 카리나 이 스타일링!
# https://post.naver.com/viewer/postView.naver?volumeNo=36357198&memberNo=34005890&vType=VERTICAL
# 제2의 카리나로 불리는 하이브 연습생 노윤아 (알유넥스트)
# https://blog.naver.com/nadiatear0/223166858457
# 에스파 카리나 데뷔부터 나의 여돌 최애 >_<
# https://blog.naver.com/nyang9523/223204965033

# %%
base = dom.find(attrs={'class':'total_group'})

for node in base.find_all('img'):
    if node.has_attr('src'):
        print(urljoin(resp.request.url, node.attrs['src']))
# Out:
# https://search.pstatic.net/sunny?src=https%3A%2F%2Fi.namu.wiki%2Fi%2FvPl_i1cUDFiiaN0L-UfORDLb-_XyBnETXuoTtem8OE7qyEzxPBL4A43Da80d0cr3bkuxce5lS6QQwr2-VTqYEg.webp&type=fff264_180

# %%
###=======================이제는 cSS Selector 볼거임.
